# %%
import os
import cv2
import random
import numpy as np
from collections import Counter
from sklearn import metrics
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import Sequential, Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.layers import Activation, Flatten, Dropout, BatchNormalization, Conv2D
from tensorflow.keras.layers import AveragePooling2D, Dense, Input, Lambda, concatenate
from tensorflow.keras.optimizers import RMSprop, Adam

# %%
folders = sorted(os.listdir("data_organized"))
train_val_patients = []
test_patients = []
test_count = 0
random.shuffle(folders)

for name in folders:
    train_val_patients.append(name)
    
for name in folders:
    _, count = name.split('+')
    # Fill up test_patients with 62 first
    count = int(count)
    if test_count+count <= 62:
        test_patients.append(name)
        test_count += count
        train_val_patients.remove(name)
        if test_count == 62:
            break
    elif test_count+count > 62:
        continue
        
print(test_count)
# Out:
# 62

# %%
# Read in files from folders, store as np arrays of images (X_train) and clinsig labels (y_train)
# clinsig TRUE = 1, FALSE = 0
X_clinsig = []
y_clinsig = []

X_indolent = []
y_indolent = []

for folder in train_val_patients:
    for filename in sorted(os.listdir("data_organized/{}".format(folder))):
        root, _ = os.path.splitext(filename)
        patient, fid, adc_t2, size, zone, label = root.split('+')
        img = Image.open("data_organized/{}/{}".format(folder, filename))
        img = img.resize((32, 32))
        array_gray = np.asarray(img)
        array = cv2.merge((array_gray,array_gray,array_gray)) 
        if adc_t2 == 't2':
            if label == 'TRUE':
                X_clinsig.append(array)
                y_clinsig.append(1)
            else:
                X_indolent.append(array)
                y_indolent.append(0)

# Random over-sampling to remedy imbalanced dataset
print('Original: indolent={}, clinsig={}'.format(len(y_indolent), len(y_clinsig)))
# Out:
# Original: indolent=200, clinsig=56

# %%
# Generate imgaes of minority class (clinsig)
X = []
y = []
X.extend(X_indolent)
X.extend(X_clinsig)
y.extend(y_indolent)
y.extend(y_clinsig)

datagen = ImageDataGenerator(
#                     rescale=1./255,
                    shear_range=0.05,
#                     zoom_range=[,1],
                    rotation_range=90,
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='nearest')
    
X_clinsig = np.array(X_clinsig)
y_clinsig = np.array(y_clinsig)
np.asarray(y_clinsig).astype('float32').reshape((-1,1))

for img in X_clinsig:
    img = img.reshape((1,) + img.shape)
    for x, val in zip(datagen.flow(img, batch_size=1), range(2)):
        im = x[0]
        X.append(im)
        y.append(1)

X = np.array(X)
y = np.array(y)
print(Counter(y))
print(len(X), len(y))
# Out:
# Counter({0: 200, 1: 168})
# 368 368

# %%
X, y = shuffle(X, y)

# Now split this into training and validation set
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=2)

#get the length of the train and validation data
ntrain = len(X_train)
nval = len(X_val)
print("ntrain={}, nval={}".format(ntrain, nval))
# Out:
# ntrain=276, nval=92

# %%
conv_base = ResNet50(weights='imagenet', include_top=False, input_shape=(32,32,3))
# conv_base.summary()

# %%
chanDim = 3

model = Sequential()
model.add(conv_base)

model.add(Conv2D(32, (3, 3), padding="same")) # kernel_initializer=init ? 
model.add(BatchNormalization(axis=chanDim))
model.add(Activation("relu"))

for i in range(9):
    model.add(Conv2D(32, (3, 3), padding="same")) 
    model.add(BatchNormalization(axis=chanDim))
    model.add(Activation("relu"))
    model.add(Conv2D(32, (3, 3), padding="same"))
    model.add(BatchNormalization(axis=chanDim))
    
model.add(AveragePooling2D(pool_size=(3, 3), padding="same"))
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(1, activation='sigmoid')) #Sigmoid function at the end because we have just two classes

# model.summary()

# %%
print('Number of trainable weights before freezing the conv base:', len(model.trainable_weights))
conv_base.trainable = False
print('Number of trainable weights after freezing the conv base:', len(model.trainable_weights))

# binary_crossentropy loss because its a binary classification
model.compile(loss='binary_crossentropy', optimizer=RMSprop(lr=1e-5), metrics=['acc'])
# model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(lr=3e-4), metrics=['acc'])
# Out:
# Number of trainable weights before freezing the conv base: 292
# Number of trainable weights after freezing the conv base: 80

# %%
batch_size = 64

train_datagen = ImageDataGenerator(
                    rescale=1./255,
                    shear_range=0.2,
                    zoom_range=[0.7,1],
                    horizontal_flip=True,
                    vertical_flip=True,
                    fill_mode='nearest')
val_datagen = ImageDataGenerator(rescale=1./255)

X_train = np.array(X_train)
y_train = np.array(y_train)

X_val = np.array(X_val)
y_val = np.array(y_val)

np.asarray(y_train).astype('float32').reshape((-1,1))
np.asarray(y_val).astype('float32').reshape((-1,1))

train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
history = model.fit(train_generator,
                    steps_per_epoch=ntrain//batch_size,
                    epochs=170,
                    validation_data=val_generator,
                    validation_steps=nval//batch_size)
# Out:
# Epoch 1/170
# 4/4 [==============================] - 2s 540ms/step - loss: 0.7051 - acc: 0.5377 - val_loss: 0.6930 - val_acc: 0.5625
# Epoch 2/170
# 4/4 [==============================] - 1s 175ms/step - loss: 0.7211 - acc: 0.5189 - val_loss: 0.6931 - val_acc: 0.5156
# Epoch 3/170
# 4/4 [==============================] - 1s 224ms/step - loss: 0.7056 - acc: 0.5236 - val_loss: 0.6932 - val_acc: 0.4844
# Epoch 4/170
# 4/4 [==============================] - 1s 326ms/step - loss: 0.6964 - acc: 0.5508 - val_loss: 0.6927 - val_acc: 0.5625
# Epoch 5/170
# 4/4 [==============================] - 1s 290ms/step - loss: 0.7022 - acc: 0.5195 - val_loss: 0.6929 - val_acc: 0.5312
# Epoch 6/170
# 4/4 [==============================] - 1s 275ms/step - loss: 0.7014 - acc: 0.5283 - val_loss: 0.6927 - val_acc: 0.5469
# Epoch 7/170
# 4/4 [==============================] - 1s 293ms/step - loss: 0.6956 - acc: 0.5519 - val_loss: 0.6928 - val_acc: 0.5312
# Epoch 8/170
# 4/4 [==============================] - 1s 268ms/step - loss: 0.6854 - acc: 0.5943 - val_loss: 0.6923 - val_acc: 0.5625
# Epoch 9/170
# 4/4 [==============================] - 1s 233ms/step - loss: 0.7102 - acc: 0.5189 - val_loss: 0.6934 - val_acc: 0.4844
# Epoch 10/170
# 4/4 [==============================] - 1s 188ms/step - loss: 0.7060 - acc: 0.5377 - val_loss: 0.6920 - val_acc: 0.5625
# Epoch 11/170
# 4/4 [==============================] - 1s 198ms/step - loss: 0.6834 - acc: 0.5991 - val_loss: 0.6926 - val_acc: 0.5312
# Epoch 12/170
# 4/4 [==============================] - 1s 195ms/step - loss: 0.7136 - acc: 0.5142 - val_loss: 0.6918 - val_acc: 0.5625
# Epoch 13/170
# 4/4 [==============================] - 1s 213ms/step - loss: 0.7114 - acc: 0.5377 - val_loss: 0.6921 - val_acc: 0.5469
# Epoch 14/170
# 4/4 [==============================] - 1s 180ms/step - loss: 0.7052 - acc: 0.5377 - val_loss: 0.6916 - val_acc: 0.5625
# Epoch 15/170
# 4/4 [==============================] - 1s 177ms/step - loss: 0.6943 - acc: 0.5283 - val_loss: 0.6924 - val_acc: 0.5312
# Epoch 16/170
# 4/4 [==============================] - 1s 268ms/step - loss: 0.6928 - acc: 0.5283 - val_loss: 0.6909 - val_acc: 0.5781
# Epoch 17/170
# 4/4 [==============================] - 1s 169ms/step - loss: 0.7066 - acc: 0.5283 - val_loss: 0.6928 - val_acc: 0.5156
# Epoch 18/170
# 4/4 [==============================] - 1s 203ms/step - loss: 0.6973 - acc: 0.5283 - val_loss: 0.6938 - val_acc: 0.4844
# Epoch 19/170
# 4/4 [==============================] - 1s 278ms/step - loss: 0.7067 - acc: 0.5142 - val_loss: 0.6906 - val_acc: 0.5781
# Epoch 20/170
# 4/4 [==============================] - 1s 212ms/step - loss: 0.7022 - acc: 0.5425 - val_loss: 0.6933 - val_acc: 0.5000
# Epoch 21/170
# 4/4 [==============================] - 1s 171ms/step - loss: 0.6926 - acc: 0.5236 - val_loss: 0.6909 - val_acc: 0.5625
# Epoch 22/170
# 4/4 [==============================] - 1s 192ms/step - loss: 0.6857 - acc: 0.5377 - val_loss: 0.6908 - val_acc: 0.5625
# Epoch 23/170
# 4/4 [==============================] - 1s 232ms/step - loss: 0.6965 - acc: 0.5508 - val_loss: 0.6914 - val_acc: 0.5469
# Epoch 24/170
# 4/4 [==============================] - 1s 196ms/step - loss: 0.7080 - acc: 0.5377 - val_loss: 0.6927 - val_acc: 0.5156
# Epoch 25/170
# 4/4 [==============================] - 1s 260ms/step - loss: 0.6965 - acc: 0.5312 - val_loss: 0.6927 - val_acc: 0.5156
# Epoch 26/170
# 4/4 [==============================] - 1s 166ms/step - loss: 0.7054 - acc: 0.4858 - val_loss: 0.6897 - val_acc: 0.5781
# Epoch 27/170
# 4/4 [==============================] - 1s 181ms/step - loss: 0.7140 - acc: 0.5047 - val_loss: 0.6911 - val_acc: 0.5469
# Epoch 28/170
# 4/4 [==============================] - 1s 263ms/step - loss: 0.6933 - acc: 0.5519 - val_loss: 0.6910 - val_acc: 0.5469
# Epoch 29/170
# 4/4 [==============================] - 1s 207ms/step - loss: 0.6892 - acc: 0.5472 - val_loss: 0.6885 - val_acc: 0.5938
# Epoch 30/170
# 4/4 [==============================] - 1s 210ms/step - loss: 0.7091 - acc: 0.5425 - val_loss: 0.6866 - val_acc: 0.6250
# Epoch 31/170
# 4/4 [==============================] - 1s 185ms/step - loss: 0.6851 - acc: 0.6226 - val_loss: 0.6917 - val_acc: 0.5312
# Epoch 32/170
# 4/4 [==============================] - 1s 257ms/step - loss: 0.6922 - acc: 0.5660 - val_loss: 0.6917 - val_acc: 0.5312
# Epoch 33/170
# 4/4 [==============================] - 1s 229ms/step - loss: 0.6926 - acc: 0.5330 - val_loss: 0.6887 - val_acc: 0.5781
# Epoch 34/170
# 4/4 [==============================] - 1s 215ms/step - loss: 0.7022 - acc: 0.5156 - val_loss: 0.6886 - val_acc: 0.5781
# Epoch 35/170
# 4/4 [==============================] - 1s 229ms/step - loss: 0.6952 - acc: 0.5377 - val_loss: 0.6875 - val_acc: 0.5938
# Epoch 36/170
# 4/4 [==============================] - 1s 187ms/step - loss: 0.6773 - acc: 0.5472 - val_loss: 0.6862 - val_acc: 0.6094
# Epoch 37/170
# 4/4 [==============================] - 1s 287ms/step - loss: 0.7052 - acc: 0.5469 - val_loss: 0.6905 - val_acc: 0.5469
# Epoch 38/170
# 4/4 [==============================] - 1s 273ms/step - loss: 0.6985 - acc: 0.5519 - val_loss: 0.6847 - val_acc: 0.6250
# Epoch 39/170
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6878 - acc: 0.5377 - val_loss: 0.6856 - val_acc: 0.6094
# Epoch 40/170
# 4/4 [==============================] - 1s 248ms/step - loss: 0.6984 - acc: 0.5425 - val_loss: 0.6879 - val_acc: 0.5781
# Epoch 41/170
# 4/4 [==============================] - 1s 228ms/step - loss: 0.6979 - acc: 0.5195 - val_loss: 0.6902 - val_acc: 0.5469
# Epoch 42/170
# 4/4 [==============================] - 1s 195ms/step - loss: 0.6944 - acc: 0.5425 - val_loss: 0.6864 - val_acc: 0.5938
# Epoch 43/170
# 4/4 [==============================] - 1s 191ms/step - loss: 0.6843 - acc: 0.5755 - val_loss: 0.6914 - val_acc: 0.5312
# Epoch 44/170
# 4/4 [==============================] - 1s 234ms/step - loss: 0.6898 - acc: 0.5508 - val_loss: 0.6901 - val_acc: 0.5469
# Epoch 45/170
# 4/4 [==============================] - 1s 240ms/step - loss: 0.7073 - acc: 0.5189 - val_loss: 0.6900 - val_acc: 0.5469
# Epoch 46/170
# 4/4 [==============================] - 1s 288ms/step - loss: 0.7081 - acc: 0.5391 - val_loss: 0.6872 - val_acc: 0.5781
# Epoch 47/170
# 4/4 [==============================] - 1s 262ms/step - loss: 0.7103 - acc: 0.5391 - val_loss: 0.6942 - val_acc: 0.5000
# Epoch 48/170
# 4/4 [==============================] - 1s 212ms/step - loss: 0.6844 - acc: 0.5425 - val_loss: 0.6884 - val_acc: 0.5625
# Epoch 49/170
# 4/4 [==============================] - 1s 233ms/step - loss: 0.6980 - acc: 0.5377 - val_loss: 0.6867 - val_acc: 0.5781
# Epoch 50/170
# 4/4 [==============================] - 1s 226ms/step - loss: 0.7009 - acc: 0.5234 - val_loss: 0.6897 - val_acc: 0.5469
# Epoch 51/170
# 4/4 [==============================] - 1s 217ms/step - loss: 0.6909 - acc: 0.5519 - val_loss: 0.6897 - val_acc: 0.5469
# Epoch 52/170
# 4/4 [==============================] - 1s 196ms/step - loss: 0.6984 - acc: 0.5425 - val_loss: 0.6929 - val_acc: 0.5156
# Epoch 53/170
# 4/4 [==============================] - 1s 239ms/step - loss: 0.7006 - acc: 0.4953 - val_loss: 0.6945 - val_acc: 0.5000
# Epoch 54/170
# 4/4 [==============================] - 1s 240ms/step - loss: 0.6924 - acc: 0.5236 - val_loss: 0.6861 - val_acc: 0.5781
# Epoch 55/170
# 4/4 [==============================] - 1s 235ms/step - loss: 0.7040 - acc: 0.5094 - val_loss: 0.6930 - val_acc: 0.5156
# Epoch 56/170
# 4/4 [==============================] - 1s 215ms/step - loss: 0.6929 - acc: 0.5613 - val_loss: 0.6840 - val_acc: 0.5938
# Epoch 57/170
# 4/4 [==============================] - 1s 238ms/step - loss: 0.6921 - acc: 0.5312 - val_loss: 0.6949 - val_acc: 0.5000
# Epoch 58/170
# 4/4 [==============================] - 1s 173ms/step - loss: 0.6829 - acc: 0.5519 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 59/170
# 4/4 [==============================] - 1s 215ms/step - loss: 0.6928 - acc: 0.5330 - val_loss: 0.6951 - val_acc: 0.5000
# Epoch 60/170
# 4/4 [==============================] - 1s 211ms/step - loss: 0.6814 - acc: 0.5508 - val_loss: 0.6892 - val_acc: 0.5469
# Epoch 61/170
# 4/4 [==============================] - 1s 197ms/step - loss: 0.6961 - acc: 0.5425 - val_loss: 0.6810 - val_acc: 0.6094
# Epoch 62/170
# 4/4 [==============================] - 1s 197ms/step - loss: 0.6964 - acc: 0.5613 - val_loss: 0.6933 - val_acc: 0.5156
# Epoch 63/170
# 4/4 [==============================] - 1s 173ms/step - loss: 0.6884 - acc: 0.5283 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 64/170
# 4/4 [==============================] - 1s 182ms/step - loss: 0.7023 - acc: 0.5377 - val_loss: 0.6934 - val_acc: 0.5156
# Epoch 65/170
# 4/4 [==============================] - 1s 184ms/step - loss: 0.6860 - acc: 0.5755 - val_loss: 0.6868 - val_acc: 0.5625
# Epoch 66/170
# 4/4 [==============================] - 1s 185ms/step - loss: 0.6979 - acc: 0.5142 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 67/170
# 4/4 [==============================] - 1s 199ms/step - loss: 0.7092 - acc: 0.5142 - val_loss: 0.6866 - val_acc: 0.5625
# Epoch 68/170
# 4/4 [==============================] - 1s 191ms/step - loss: 0.6842 - acc: 0.5425 - val_loss: 0.6843 - val_acc: 0.5781
# Epoch 69/170
# 4/4 [==============================] - 1s 222ms/step - loss: 0.6941 - acc: 0.5391 - val_loss: 0.6748 - val_acc: 0.6406
# Epoch 70/170
# 4/4 [==============================] - 1s 177ms/step - loss: 0.6817 - acc: 0.5189 - val_loss: 0.6865 - val_acc: 0.5625
# Epoch 71/170
# 4/4 [==============================] - 1s 183ms/step - loss: 0.6835 - acc: 0.5425 - val_loss: 0.6841 - val_acc: 0.5781
# Epoch 72/170
# 4/4 [==============================] - 1s 253ms/step - loss: 0.6927 - acc: 0.5283 - val_loss: 0.6937 - val_acc: 0.5156
# Epoch 73/170
# 4/4 [==============================] - 1s 237ms/step - loss: 0.6789 - acc: 0.5802 - val_loss: 0.6986 - val_acc: 0.4844
# Epoch 74/170
# 4/4 [==============================] - 1s 278ms/step - loss: 0.6948 - acc: 0.5189 - val_loss: 0.7011 - val_acc: 0.4688
# Epoch 75/170
# 4/4 [==============================] - 1s 218ms/step - loss: 0.7063 - acc: 0.4906 - val_loss: 0.7012 - val_acc: 0.4688
# Epoch 76/170
# 4/4 [==============================] - 1s 232ms/step - loss: 0.7001 - acc: 0.5472 - val_loss: 0.6964 - val_acc: 0.5000
# Epoch 77/170
# 4/4 [==============================] - 1s 187ms/step - loss: 0.6799 - acc: 0.5472 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 78/170
# 4/4 [==============================] - 1s 229ms/step - loss: 0.6902 - acc: 0.5000 - val_loss: 0.6836 - val_acc: 0.5781
# Epoch 79/170
# 4/4 [==============================] - 1s 191ms/step - loss: 0.6992 - acc: 0.4906 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 80/170
# 4/4 [==============================] - 1s 174ms/step - loss: 0.6758 - acc: 0.5802 - val_loss: 0.6912 - val_acc: 0.5312
# Epoch 81/170
# 4/4 [==============================] - 1s 200ms/step - loss: 0.6919 - acc: 0.4858 - val_loss: 0.6809 - val_acc: 0.5938
# Epoch 82/170
# 4/4 [==============================] - 1s 169ms/step - loss: 0.6771 - acc: 0.5566 - val_loss: 0.6941 - val_acc: 0.5156
# Epoch 83/170
# 4/4 [==============================] - 1s 172ms/step - loss: 0.6903 - acc: 0.5425 - val_loss: 0.6862 - val_acc: 0.5625
# Epoch 84/170
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6904 - acc: 0.5660 - val_loss: 0.6943 - val_acc: 0.5156
# Epoch 85/170
# 4/4 [==============================] - 1s 227ms/step - loss: 0.6815 - acc: 0.5519 - val_loss: 0.6861 - val_acc: 0.5625
# Epoch 86/170
# 4/4 [==============================] - 1s 201ms/step - loss: 0.6833 - acc: 0.5330 - val_loss: 0.6971 - val_acc: 0.5000
# Epoch 87/170
# 4/4 [==============================] - 1s 247ms/step - loss: 0.6985 - acc: 0.5312 - val_loss: 0.6859 - val_acc: 0.5625
# Epoch 88/170
# 4/4 [==============================] - 1s 263ms/step - loss: 0.6950 - acc: 0.5613 - val_loss: 0.7054 - val_acc: 0.4531
# Epoch 89/170
# 4/4 [==============================] - 1s 249ms/step - loss: 0.6785 - acc: 0.5896 - val_loss: 0.6888 - val_acc: 0.5469
# Epoch 90/170
# 4/4 [==============================] - 1s 215ms/step - loss: 0.6993 - acc: 0.5330 - val_loss: 0.6888 - val_acc: 0.5469
# Epoch 91/170
# 4/4 [==============================] - 1s 189ms/step - loss: 0.6806 - acc: 0.5755 - val_loss: 0.6886 - val_acc: 0.5469
# Epoch 92/170
# 4/4 [==============================] - 1s 240ms/step - loss: 0.6974 - acc: 0.5236 - val_loss: 0.6833 - val_acc: 0.5781
# Epoch 93/170
# 4/4 [==============================] - 1s 256ms/step - loss: 0.6845 - acc: 0.5519 - val_loss: 0.6891 - val_acc: 0.5469
# Epoch 94/170
# 4/4 [==============================] - 1s 278ms/step - loss: 0.7041 - acc: 0.5094 - val_loss: 0.6921 - val_acc: 0.5312
# Epoch 95/170
# 4/4 [==============================] - 1s 252ms/step - loss: 0.6778 - acc: 0.5330 - val_loss: 0.6946 - val_acc: 0.5156
# Epoch 96/170
# 4/4 [==============================] - 1s 269ms/step - loss: 0.6923 - acc: 0.5094 - val_loss: 0.6972 - val_acc: 0.5000
# Epoch 97/170
# 4/4 [==============================] - 1s 186ms/step - loss: 0.6866 - acc: 0.5660 - val_loss: 0.6966 - val_acc: 0.5000
# Epoch 98/170
# 4/4 [==============================] - 1s 241ms/step - loss: 0.6821 - acc: 0.5519 - val_loss: 0.6843 - val_acc: 0.5781
# Epoch 99/170
# 4/4 [==============================] - 1s 226ms/step - loss: 0.7046 - acc: 0.5189 - val_loss: 0.6808 - val_acc: 0.5938
# Epoch 100/170
# 4/4 [==============================] - 1s 199ms/step - loss: 0.6924 - acc: 0.5312 - val_loss: 0.6944 - val_acc: 0.5156
# Epoch 101/170
# 4/4 [==============================] - 1s 160ms/step - loss: 0.6750 - acc: 0.5802 - val_loss: 0.6948 - val_acc: 0.5156
# Epoch 102/170
# 4/4 [==============================] - 1s 182ms/step - loss: 0.6714 - acc: 0.5991 - val_loss: 0.6882 - val_acc: 0.5625
# Epoch 103/170
# 4/4 [==============================] - 1s 160ms/step - loss: 0.6897 - acc: 0.5566 - val_loss: 0.6919 - val_acc: 0.5312
# Epoch 104/170
# 4/4 [==============================] - 1s 230ms/step - loss: 0.6970 - acc: 0.5094 - val_loss: 0.6878 - val_acc: 0.5625
# Epoch 105/170
# 4/4 [==============================] - 1s 255ms/step - loss: 0.6846 - acc: 0.5708 - val_loss: 0.6889 - val_acc: 0.5625
# Epoch 106/170
# 4/4 [==============================] - 1s 340ms/step - loss: 0.6943 - acc: 0.5625 - val_loss: 0.6940 - val_acc: 0.5312
# Epoch 107/170
# 4/4 [==============================] - 1s 201ms/step - loss: 0.7078 - acc: 0.5094 - val_loss: 0.7014 - val_acc: 0.5000
# Epoch 108/170
# 4/4 [==============================] - 1s 193ms/step - loss: 0.6830 - acc: 0.5755 - val_loss: 0.6893 - val_acc: 0.5625
# Epoch 109/170
# 4/4 [==============================] - 1s 180ms/step - loss: 0.6713 - acc: 0.5849 - val_loss: 0.6882 - val_acc: 0.5625
# Epoch 110/170
# 4/4 [==============================] - 1s 193ms/step - loss: 0.7006 - acc: 0.4953 - val_loss: 0.6951 - val_acc: 0.5312
# Epoch 111/170
# 4/4 [==============================] - 1s 254ms/step - loss: 0.6839 - acc: 0.5566 - val_loss: 0.6940 - val_acc: 0.5156
# Epoch 112/170
# 4/4 [==============================] - 1s 165ms/step - loss: 0.6891 - acc: 0.5330 - val_loss: 0.6839 - val_acc: 0.5781
# Epoch 113/170
# 4/4 [==============================] - 1s 336ms/step - loss: 0.6842 - acc: 0.5352 - val_loss: 0.6989 - val_acc: 0.5156
# Epoch 114/170
# 4/4 [==============================] - 1s 187ms/step - loss: 0.6872 - acc: 0.5708 - val_loss: 0.6822 - val_acc: 0.5938
# Epoch 115/170
# 4/4 [==============================] - 1s 204ms/step - loss: 0.6954 - acc: 0.5425 - val_loss: 0.6955 - val_acc: 0.5156
# Epoch 116/170
# 4/4 [==============================] - 1s 251ms/step - loss: 0.6909 - acc: 0.5312 - val_loss: 0.7061 - val_acc: 0.4844
# Epoch 117/170
# 4/4 [==============================] - 1s 267ms/step - loss: 0.6810 - acc: 0.5660 - val_loss: 0.6981 - val_acc: 0.5312
# Epoch 118/170
# 4/4 [==============================] - 1s 240ms/step - loss: 0.6949 - acc: 0.5330 - val_loss: 0.6869 - val_acc: 0.5781
# Epoch 119/170
# 4/4 [==============================] - 1s 212ms/step - loss: 0.6764 - acc: 0.5802 - val_loss: 0.6813 - val_acc: 0.6094
# Epoch 120/170
# 4/4 [==============================] - 1s 222ms/step - loss: 0.6917 - acc: 0.5430 - val_loss: 0.6951 - val_acc: 0.5156
# Epoch 121/170
# 4/4 [==============================] - 1s 213ms/step - loss: 0.6985 - acc: 0.5283 - val_loss: 0.6958 - val_acc: 0.5156
# Epoch 122/170
# 4/4 [==============================] - 1s 253ms/step - loss: 0.6909 - acc: 0.5377 - val_loss: 0.6983 - val_acc: 0.4688
# Epoch 123/170
# 4/4 [==============================] - 1s 218ms/step - loss: 0.6967 - acc: 0.5377 - val_loss: 0.6788 - val_acc: 0.6094
# Epoch 124/170
# 4/4 [==============================] - 1s 178ms/step - loss: 0.6814 - acc: 0.5425 - val_loss: 0.6889 - val_acc: 0.5312
# Epoch 125/170
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6754 - acc: 0.5802 - val_loss: 0.6988 - val_acc: 0.5000
# Epoch 126/170
# 4/4 [==============================] - 1s 160ms/step - loss: 0.6950 - acc: 0.5236 - val_loss: 0.6926 - val_acc: 0.5625
# Epoch 127/170
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6823 - acc: 0.5943 - val_loss: 0.6949 - val_acc: 0.5469
# Epoch 128/170
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6932 - acc: 0.5708 - val_loss: 0.7010 - val_acc: 0.5000
# Epoch 129/170
# 4/4 [==============================] - 1s 174ms/step - loss: 0.7003 - acc: 0.5519 - val_loss: 0.6829 - val_acc: 0.5938
# Epoch 130/170
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6969 - acc: 0.4906 - val_loss: 0.7035 - val_acc: 0.4688
# Epoch 131/170
# 4/4 [==============================] - 1s 158ms/step - loss: 0.6791 - acc: 0.5613 - val_loss: 0.6865 - val_acc: 0.5781
# Epoch 132/170
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6841 - acc: 0.5566 - val_loss: 0.7029 - val_acc: 0.5000
# Epoch 133/170
# 4/4 [==============================] - 1s 177ms/step - loss: 0.6865 - acc: 0.5472 - val_loss: 0.6999 - val_acc: 0.5625
# Epoch 134/170
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6668 - acc: 0.5802 - val_loss: 0.6878 - val_acc: 0.6250
# Epoch 135/170
# 4/4 [==============================] - 1s 158ms/step - loss: 0.6836 - acc: 0.5613 - val_loss: 0.7064 - val_acc: 0.5156
# Epoch 136/170
# 4/4 [==============================] - 1s 185ms/step - loss: 0.6843 - acc: 0.5425 - val_loss: 0.6941 - val_acc: 0.5938
# Epoch 137/170
# 4/4 [==============================] - 1s 188ms/step - loss: 0.6889 - acc: 0.4953 - val_loss: 0.6989 - val_acc: 0.5312
# Epoch 138/170
# 4/4 [==============================] - 1s 173ms/step - loss: 0.6941 - acc: 0.5283 - val_loss: 0.7007 - val_acc: 0.5000
# Epoch 139/170
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6873 - acc: 0.5566 - val_loss: 0.6991 - val_acc: 0.5312
# Epoch 140/170
# 4/4 [==============================] - 1s 154ms/step - loss: 0.6901 - acc: 0.5236 - val_loss: 0.6843 - val_acc: 0.5625
# Epoch 141/170
# 4/4 [==============================] - 1s 152ms/step - loss: 0.6898 - acc: 0.5236 - val_loss: 0.6959 - val_acc: 0.5156
# Epoch 142/170
# 4/4 [==============================] - 1s 175ms/step - loss: 0.6922 - acc: 0.5469 - val_loss: 0.6955 - val_acc: 0.5000
# Epoch 143/170
# 4/4 [==============================] - 1s 177ms/step - loss: 0.6913 - acc: 0.5660 - val_loss: 0.6884 - val_acc: 0.5625
# Epoch 144/170
# 4/4 [==============================] - 1s 178ms/step - loss: 0.6912 - acc: 0.5508 - val_loss: 0.6952 - val_acc: 0.5156
# Epoch 145/170
# 4/4 [==============================] - 1s 163ms/step - loss: 0.6905 - acc: 0.5283 - val_loss: 0.6827 - val_acc: 0.5469
# Epoch 146/170
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6877 - acc: 0.5377 - val_loss: 0.6865 - val_acc: 0.5156
# Epoch 147/170
# 4/4 [==============================] - 1s 158ms/step - loss: 0.6825 - acc: 0.5660 - val_loss: 0.6811 - val_acc: 0.5781
# Epoch 148/170
# 4/4 [==============================] - 1s 160ms/step - loss: 0.6889 - acc: 0.5330 - val_loss: 0.6929 - val_acc: 0.5156
# Epoch 149/170
# 4/4 [==============================] - 1s 151ms/step - loss: 0.6952 - acc: 0.5236 - val_loss: 0.6921 - val_acc: 0.5000
# Epoch 150/170
# 4/4 [==============================] - 1s 176ms/step - loss: 0.6897 - acc: 0.5142 - val_loss: 0.6950 - val_acc: 0.5000
# Epoch 151/170
# 4/4 [==============================] - 1s 177ms/step - loss: 0.7127 - acc: 0.4575 - val_loss: 0.6950 - val_acc: 0.5625
# Epoch 152/170
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6860 - acc: 0.5613 - val_loss: 0.7072 - val_acc: 0.5156
# Epoch 153/170
# 4/4 [==============================] - 1s 175ms/step - loss: 0.6840 - acc: 0.5391 - val_loss: 0.6904 - val_acc: 0.5469
# Epoch 154/170
# 4/4 [==============================] - 1s 156ms/step - loss: 0.6983 - acc: 0.5236 - val_loss: 0.6865 - val_acc: 0.6406
# Epoch 155/170
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6891 - acc: 0.5330 - val_loss: 0.6959 - val_acc: 0.5781
# Epoch 156/170
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6866 - acc: 0.5472 - val_loss: 0.6944 - val_acc: 0.5625
# Epoch 157/170
# 4/4 [==============================] - 1s 164ms/step - loss: 0.6805 - acc: 0.5943 - val_loss: 0.6925 - val_acc: 0.5312
# Epoch 158/170
# 4/4 [==============================] - 1s 160ms/step - loss: 0.6940 - acc: 0.5283 - val_loss: 0.6980 - val_acc: 0.5156
# Epoch 159/170
# 4/4 [==============================] - 1s 155ms/step - loss: 0.6819 - acc: 0.5708 - val_loss: 0.7003 - val_acc: 0.5000
# Epoch 160/170
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6924 - acc: 0.5330 - val_loss: 0.6824 - val_acc: 0.5781
# Epoch 161/170
# 4/4 [==============================] - 1s 181ms/step - loss: 0.6869 - acc: 0.5273 - val_loss: 0.6887 - val_acc: 0.5469
# Epoch 162/170
# 4/4 [==============================] - 1s 178ms/step - loss: 0.6918 - acc: 0.5755 - val_loss: 0.6844 - val_acc: 0.5938
# Epoch 163/170
# 4/4 [==============================] - 1s 154ms/step - loss: 0.6838 - acc: 0.5472 - val_loss: 0.7043 - val_acc: 0.4844
# Epoch 164/170
# 4/4 [==============================] - 1s 154ms/step - loss: 0.6620 - acc: 0.6179 - val_loss: 0.6893 - val_acc: 0.5625
# Epoch 165/170
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6917 - acc: 0.5000 - val_loss: 0.6761 - val_acc: 0.5781
# Epoch 166/170
# 4/4 [==============================] - 1s 159ms/step - loss: 0.6725 - acc: 0.5425 - val_loss: 0.6971 - val_acc: 0.4844
# Epoch 167/170
# 4/4 [==============================] - 1s 150ms/step - loss: 0.6868 - acc: 0.5377 - val_loss: 0.7011 - val_acc: 0.4844
# Epoch 168/170
# 4/4 [==============================] - 1s 176ms/step - loss: 0.6845 - acc: 0.5586 - val_loss: 0.7066 - val_acc: 0.4531
# Epoch 169/170
# 4/4 [==============================] - 1s 157ms/step - loss: 0.6817 - acc: 0.5613 - val_loss: 0.6978 - val_acc: 0.5469
# Epoch 170/170
# 4/4 [==============================] - 1s 156ms/step - loss: 0.6743 - acc: 0.5755 - val_loss: 0.6510 - val_acc: 0.7188

# %%
model.save_weights('models/model_t2_weights.h5')
model.save('models/model_t2_keras.h5')

# %%
# Plot validation and losss

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

#Train and validation accuracy
plt.plot(epochs, acc, 'b', label='Training accurarcy')
plt.plot(epochs, val_acc, 'r', label='Validation accurarcy')
plt.title('Training and Validation accurarcy')
plt.legend()

plt.figure()
#Train and validation loss
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
# Plot validation and losss with smoother lines

def smooth_plot(points, factor=0.7):
    smooth_pts = []
    for point in points:
        if smooth_pts:
            previous = smooth_pts[-1]
            smooth_pts.append(previous * factor + point * (1 - factor))
        else:
            smooth_pts.append(point)
    return smooth_pts

#Plot figure
plt.plot(epochs, smooth_plot(acc), 'b', label='Training accuracy')
plt.plot(epochs, smooth_plot(val_acc), 'r', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.legend()
plt.show()

plt.plot(epochs, smooth_plot(loss), 'b', label='Training loss')
plt.plot(epochs, smooth_plot(val_loss), 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()
plt.show()

# %%
#Prepare test set

X_test = []
y_test = []

for folder in test_patients:
    for filename in sorted(os.listdir("data_organized/{}".format(folder))):
        root, _ = os.path.splitext(filename)
        patient, fid, adc_t2, size, zone, label = root.split('+')
        if adc_t2 == 't2':
            if label == 'TRUE':
                y_test.append(1)
            else:
                y_test.append(0)
        img = Image.open("data_organized/{}/{}".format(folder, filename))
        img = img.resize((32, 32))
        array_gray = np.asarray(img)
        array = cv2.merge((array_gray,array_gray,array_gray))  
        if adc_t2 == 't2':
            X_test.append(array)
            
print(len(X_test), len(y_test))
# Out:
# 62 62

# %%
x = np.array(X_test)
y = np.array(y_test)
y_pred_class = []
y_pred_prob = []
test_datagen = ImageDataGenerator(rescale=1./255)

correct = 0
true_pos = 0
true_neg = 0
false_pos = 0
false_neg = 0
i = 0
for batch in test_datagen.flow(x, batch_size=1):
    if i == len(x):
        break
    prob = model.predict(batch)
    y_pred_prob.append(prob)
    prediction = int(np.round(prob))
    y_pred_class.append(prediction)
    actual = y[i]
    if prediction == actual:
        correct += 1
        if prediction == 1:
            true_pos += 1
        else:
            true_neg += 1
    else:
        if prediction == 1 and actual == 0:
            false_pos += 1
        else:
            false_neg += 1
    i += 1

# %%
print('ACCURACY:', metrics.accuracy_score(y, y_pred_class))
print('SENSITIVITY:', metrics.recall_score(y, y_pred_class))
print('SPECIFICITY:', true_neg / (true_neg + false_pos))

y_prob = np.array(y_pred_prob).reshape((len(y_pred_prob),))
fpr, tpr, thresholds = metrics.roc_curve(y,y_prob)

print(','.join(str(x) for x in fpr))
print(','.join(str(x) for x in tpr))

plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

print('AUC SCORE:', metrics.roc_auc_score(y,y_prob))
# Out:
# ACCURACY: 0.6774193548387096
# SENSITIVITY: 0.1111111111111111
# SPECIFICITY: 0.9090909090909091
# 0.0,0.0,0.0,0.09090909090909091,0.09090909090909091,0.20454545454545456,0.20454545454545456,0.22727272727272727,0.22727272727272727,0.3409090909090909,0.3409090909090909,0.38636363636363635,0.38636363636363635,0.4318181818181818,0.4318181818181818,0.5227272727272727,0.5227272727272727,0.5909090909090909,0.5909090909090909,0.6590909090909091,0.6590909090909091,0.7954545454545454,0.7954545454545454,0.9090909090909091,0.9090909090909091,0.9545454545454546,0.9545454545454546,1.0,1.0
# 0.0,0.05555555555555555,0.1111111111111111,0.1111111111111111,0.16666666666666666,0.16666666666666666,0.3333333333333333,0.3333333333333333,0.3888888888888889,0.3888888888888889,0.4444444444444444,0.4444444444444444,0.5,0.5,0.5555555555555556,0.5555555555555556,0.6111111111111112,0.6111111111111112,0.6666666666666666,0.6666666666666666,0.7222222222222222,0.7222222222222222,0.7777777777777778,0.7777777777777778,0.8888888888888888,0.8888888888888888,0.9444444444444444,0.9444444444444444,1.0
# AUC SCORE: 0.5315656565656566

# %%
def evaluate_threshold(threshold):
    print('Sensitivity:', tpr[thresholds > threshold][-1])
    print('Specificity:', 1 - fpr[thresholds > threshold][-1])

evaluate_threshold(0.45)
# Out:
# Sensitivity: 0.5555555555555556
# Specificity: 0.5681818181818181

# %%
precision, recall, thresholds = metrics.precision_recall_curve(y,y_prob)
print('PRECISION')
print(','.join(str(x) for x in precision))
print()
print('RECALL')
print(','.join(str(x) for x in recall))
# Out:
# PRECISION
# 0.2903225806451613,0.2786885245901639,0.2833333333333333,0.288135593220339,0.27586206896551724,0.2807017543859649,0.2857142857142857,0.2727272727272727,0.25925925925925924,0.2641509433962264,0.2692307692307692,0.27450980392156865,0.28,0.2857142857142857,0.2708333333333333,0.2765957446808511,0.2826086956521739,0.28888888888888886,0.29545454545454547,0.3023255813953488,0.30952380952380953,0.2926829268292683,0.3,0.3076923076923077,0.3157894736842105,0.2972972972972973,0.3055555555555556,0.3142857142857143,0.3235294117647059,0.30303030303030304,0.3125,0.3225806451612903,0.3333333333333333,0.3448275862068966,0.32142857142857145,0.3333333333333333,0.34615384615384615,0.32,0.3333333333333333,0.34782608695652173,0.3181818181818182,0.3333333333333333,0.35,0.3684210526315789,0.3888888888888889,0.4117647058823529,0.375,0.4,0.35714285714285715,0.3076923076923077,0.25,0.2727272727272727,0.3,0.3333333333333333,0.375,0.42857142857142855,0.3333333333333333,0.4,0.5,0.6666666666666666,1.0,1.0,1.0
#
# RECALL
# 1.0,0.9444444444444444,0.9444444444444444,0.9444444444444444,0.8888888888888888,0.8888888888888888,0.8888888888888888,0.8333333333333334,0.7777777777777778,0.7777777777777778,0.7777777777777778,0.7777777777777778,0.7777777777777778,0.7777777777777778,0.7222222222222222,0.7222222222222222,0.7222222222222222,0.7222222222222222,0.7222222222222222,0.7222222222222222,0.7222222222222222,0.6666666666666666,0.6666666666666666,0.6666666666666666,0.6666666666666666,0.6111111111111112,0.6111111111111112,0.6111111111111112,0.6111111111111112,0.5555555555555556,0.5555555555555556,0.5555555555555556,0.5555555555555556,0.5555555555555556,0.5,0.5,0.5,0.4444444444444444,0.4444444444444444,0.4444444444444444,0.3888888888888889,0.3888888888888889,0.3888888888888889,0.3888888888888889,0.3888888888888889,0.3888888888888889,0.3333333333333333,0.3333333333333333,0.2777777777777778,0.2222222222222222,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.16666666666666666,0.1111111111111111,0.1111111111111111,0.1111111111111111,0.1111111111111111,0.1111111111111111,0.05555555555555555,0.0

# %%
plt.figure(figsize=(7, 8))
f_scores = np.linspace(0.2, 0.8, num=4)
lines = []
labels = []
for f_score in f_scores:
    x = np.linspace(0.01, 1)
    y = f_score * x / (2 * x - f_score)
    l, = plt.plot(x[y >= 0], y[y >= 0], color='gray', alpha=0.2)
    plt.annotate('f1={0:0.1f}'.format(f_score), xy=(0.9, y[45] + 0.02))

plt.plot(recall, precision, color='turquoise', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall curves')
plt.legend(lines, labels, loc=(0, -.38), prop=dict(size=14))

plt.show()
